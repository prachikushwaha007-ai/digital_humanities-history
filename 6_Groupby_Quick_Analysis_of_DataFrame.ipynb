# %% [markdown]
# <a href="https://colab.research.google.com/github/prachikushwaha007-ai/digital_humanities-history/blob/main/6_Groupby_Quick_Analysis_of_DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'

# %%
df = pd.read_csv(url)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.groupby("Sex")

# %%
df.groupby("Sex").get_group("male")
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.groupby("Age").get_group(20)
# Out:
#      PassengerId  Survived  Pclass                            Name     Sex  \
# 12            13         0       3  Saundercock, Mr. William Henry    male
# 91            92         0       3      Andreasson, Mr. Paul Edvin    male
# 113          114         0       3         Jussila, Miss. Katriina  female
# 131          132         0       3  Coelho, Mr. Domingos Fernandeo    male
# 378          379         0       3             Betros, Mr. Tannous    male
# 404          405         0       3         Oreskovic, Miss. Marija  female
# 441          442         0       3                 Hampe, Mr. Leon    male
# 622          623         1       3                Nakid, Mr. Sahid    male
# 640          641         0       3          Jensen, Mr. Hans Peder    male
# 664          665         1       3     Lindqvist, Mr. Eino William    male
# 682          683         0       3     Olsvigen, Mr. Thor Anderson    male
# ...

# %%
df.groupby("Sex").count()
# Out:
#         PassengerId  Survived  Pclass  Name  Age  SibSp  Parch  Ticket  Fare  \
# Sex
# female          314       314     314   314  261    314    314     314   314
# male            577       577     577   577  453    577    577     577   577
#
#         Cabin  Embarked
# Sex
# female     97       312
# male      107       577
