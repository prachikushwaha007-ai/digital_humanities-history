# %% [markdown]
# <a href="https://colab.research.google.com/github/prachikushwaha007-ai/digital_humanities-history/blob/main/1_Practice_lib_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
#1.3.2
import pandas as pd

# %%
names_dict={"names" : ["Tom","Jerry","Rose","Jeff","Merry","James"]}
for name in names_dict:
   print (names)
# Out:
# ['Tom', 'Jerry', 'Rose', 'Jeff', 'Merry', 'James']

# %%
df=pd.DataFrame(names_dict)
df
# Out:
#    names
# 0    Tom
# 1  Jerry
# 2   Rose
# 3   Jeff
# 4  Merry
# 5  James

# %%
print(df)
# Out:
#    names
# 0    Tom
# 1  Jerry
# 2   Rose
# 3   Jeff
# 4  Merry
# 5  James

# %%
df.to_csv("sample_data/mnist_test.csv",index=False)
df2 = pd.read_csv("sample_data/mnist_test.csv")
df2
# Out:
#    names
# 0    Tom
# 1  Jerry
# 2   Rose
# 3   Jeff
# 4  Merry
# 5  James

# %%
df2
# Out:
#    names
# 0    Tom
# 1  Jerry
# 2   Rose
# 3   Jeff
# 4  Merry
# 5  James

# %%
df2.to_json("sample_data/mnist_test.json")

# %%
df4 = pd.read_json("sample_data/mnist_test.json")

# %%
df4
# Out:
#    names
# 0    Tom
# 1  Jerry
# 2   Rose
# 3   Jeff
# 4  Merry
# 5  James

# %%
df4["ages"] = [20,21,25,29,31,56]

# %%
df4
# Out:
#    names  ages
# 0    Tom    20
# 1  Jerry    21
# 2   Rose    25
# 3   Jeff    29
# 4  Merry    31
# 5  James    56

# %%
#To grab a single column from data#
names=df4.names
names
# Out:
# 0      Tom
# 1    Jerry
# 2     Rose
# 3     Jeff
# 4    Merry
# 5    James
# Name: names, dtype: object

# %%
ages=df4.ages
ages
# Out:
# 0    20
# 1    21
# 2    25
# 3    29
# 4    31
# 5    56
# Name: ages, dtype: int64

# %%
#iloc
row1=df4.iloc[1]

# %%
row1
# Out:
# names    Jerry
# ages        21
# Name: 1, dtype: object
