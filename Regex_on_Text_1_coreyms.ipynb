# %% [markdown]
# <a href="https://colab.research.google.com/github/prachikushwaha007-ai/digital_humanities-history/blob/prachikushwaha007-ai-patch-1/Regex_on_Text_1_coreyms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
text_to_search = '''
abcdefghijklmnopqrstuvwxyz
ABCDEFGHIJKLMNOPQRSTUVWXYZ
1234567890

Ha HaHa

MetaCharacters(Need to be escaped):
. ˆ $ * + ? { } [ ] \ | ( )

coreyms.com

321-555-4321
123.555.1234
123*555*1234
800-555-4321
900-555-4321

cat
mat
pat
bat

Mr. Schafer
Mr Smith
Ms Davis
Mrs. Robinson
Mr. T
'''
# Out:
# <>:9: SyntaxWarning: invalid escape sequence '\ '
# <>:9: SyntaxWarning: invalid escape sequence '\ '
# /tmp/ipykernel_4691/2004914283.py:9: SyntaxWarning: invalid escape sequence '\ '
#   . ˆ $ * + ? { } [ ] \ | ( )

# %%
sentence = 'Start a sentence and then bring it to an end'

# %%
print('\tTab')
# Out:
# 	Tab

# %%
print(r'\tTab') # r = raw text
# Out:
# \tTab

# %%
# re.compile() method itext_to_searchs used to seperate out patterns into a variable & also reuse that variable for multiple searches
pattern = re.compile(r'abc')
matches = pattern.finditer(text_to_search)

for match in matches:
    print(match)
# Out:
# <re.Match object; span=(1, 4), match='abc'>

# %%
print(text_to_search[1:4]) # span is 1 to 4 in above output.
# Out:
# abc

# %%
pattern = re.compile(r'\D')  # \ for escaping MetaCharacters.
matches = pattern.finditer(text_to_search)

for match in matches:
  print(match)
# Out:
# <re.Match object; span=(0, 1), match='\n'>
# <re.Match object; span=(1, 2), match='a'>
# <re.Match object; span=(2, 3), match='b'>
# <re.Match object; span=(3, 4), match='c'>
# <re.Match object; span=(4, 5), match='d'>
# <re.Match object; span=(5, 6), match='e'>
# <re.Match object; span=(6, 7), match='f'>
# <re.Match object; span=(7, 8), match='g'>
# <re.Match object; span=(8, 9), match='h'>
# <re.Match object; span=(9, 10), match='i'>
# <re.Match object; span=(10, 11), match='j'>
# <re.Match object; span=(11, 12), match='k'>
# <re.Match object; span=(12, 13), match='l'>
# <re.Match object; span=(13, 14), match='m'>
# <re.Match object; span=(14, 15), match='n'>
# <re.Match object; span=(15, 16), match='o'>
# <re.Match object; span=(16, 17), match='p'>
# <re.Match object; span=(17, 18), match='q'>
# <re.Match object; span=(18, 19), match='r'>
# <re.Match object; span=(19, 20), match='s'>
# <re.Match object; span=(20, 21), match='t'>
# <re.Match object; span=(21, 22), match='u'>
# ...

# %%
pattern = re.compile(r'coreyms\.com')
matches = pattern.finditer(text_to_search)

for match in matches:
    print(match)
# Out:
# <re.Match object; span=(141, 152), match='coreyms.com'>

# %%
# 1 \.   - Any Character Except New line
# 2 \d   - Digit(0-9) , DATE FIND- 18\d\d pattern
# 3 \D   - Not a Digit (0-9)
# 4 \w   - Word Character(a-z, A-Z, 0-9, _), STYLOMETRY-NLP
# 5 \W   - Not a Word Character
# 6 \s   - Whitespace (space, tab, newline)
# 7 \S   - Not Whitespace (space, tab, newline)

# %%
# 08 \b   - Word Boundary , \bruler\b pattern find
# 09 \B   - Not a Word Boundary
# 10 ˆ    - Beginning of a String
# 11 $    - End of a String
# 12 []   - OCR Mistake in spell (Centr[ee]r)
# 13 [ˆ ] - Matches Characters NOT in Brackets
# 14 [a-zA-1-9]  -  RANGE SET

# %%
print('This cell now contains only comments related to Quantifiers.')
# Quantifiers.
# *     - 0 or more
# +     - 1 or more
# ?     - 0 or one
# {3}   - Exact Number
# {3,4} - Range of Numbers (Minimum, Maximum)
# Out:
# This cell now contains only comments related to Quantifiers.

# %%
pattern = re.compile(r'\.')
matches = pattern.finditer(text_to_search)

for match in matches:
    print(match)
# Out:
# <re.Match object; span=(112, 113), match='.'>
# <re.Match object; span=(148, 149), match='.'>
# <re.Match object; span=(170, 171), match='.'>
# <re.Match object; span=(174, 175), match='.'>
# <re.Match object; span=(239, 240), match='.'>
# <re.Match object; span=(270, 271), match='.'>
# <re.Match object; span=(283, 284), match='.'>

# %%
pattern = re.compile(r'\d\w')
matches = pattern.finditer(text_to_search)

for match in matches:
    print(match)
# Out:
# <re.Match object; span=(55, 57), match='12'>
# <re.Match object; span=(57, 59), match='34'>
# <re.Match object; span=(59, 61), match='56'>
# <re.Match object; span=(61, 63), match='78'>
# <re.Match object; span=(63, 65), match='90'>
# <re.Match object; span=(154, 156), match='32'>
# <re.Match object; span=(158, 160), match='55'>
# <re.Match object; span=(162, 164), match='43'>
# <re.Match object; span=(164, 166), match='21'>
# <re.Match object; span=(167, 169), match='12'>
# <re.Match object; span=(171, 173), match='55'>
# <re.Match object; span=(175, 177), match='12'>
# <re.Match object; span=(177, 179), match='34'>
# <re.Match object; span=(180, 182), match='12'>
# <re.Match object; span=(184, 186), match='55'>
# <re.Match object; span=(188, 190), match='12'>
# <re.Match object; span=(190, 192), match='34'>
# <re.Match object; span=(193, 195), match='80'>
# <re.Match object; span=(197, 199), match='55'>
# <re.Match object; span=(201, 203), match='43'>
# ...

# %%
pattern = re.compile(r'end$')

matches = pattern.finditer(sentence)

for match in matches:
    print(match)
# Out:
# <re.Match object; span=(41, 44), match='end'>

# %%
# Matching digits with .
pattern = re.compile(r'\d{3}.\d{3}.\d{4}')

matches = pattern.findall(text_to_search)

for match in matches:
    print(match)
# Out:
# 321-555-4321
# 123.555.1234
# 123*555*1234
# 800-555-4321
# 900-555-4321

# %%
# Matching Names having different Mr. with or without period.
pattern = re.compile(r'(Mr|Ms|Mrs)\.?\s[A-Z]\w*')

matches = pattern.finditer(text_to_search)

for match in matches:
    print(match)
# Out:
# <re.Match object; span=(237, 248), match='Mr. Schafer'>
# <re.Match object; span=(249, 257), match='Mr Smith'>
# <re.Match object; span=(258, 266), match='Ms Davis'>
# <re.Match object; span=(267, 280), match='Mrs. Robinson'>
# <re.Match object; span=(281, 286), match='Mr. T'>

# %%
# matching 3 words characters except bat in text_to_search.

pattern = re.compile(r'\b(?!bat)[a-z]at\b')

matches = pattern.finditer(text_to_search)

for match in matches:
    print(match)
# Out:
# <re.Match object; span=(220, 223), match='cat'>
# <re.Match object; span=(224, 227), match='mat'>
# <re.Match object; span=(228, 231), match='pat'>

# %%
# Opening the text file 'freedom of the seas'.
with open('/content/drive/MyDrive/freedom of the seas .txt', 'r', encoding='utf-8') as f:
    contents = f.read()

matches = pattern.finditer(contents)

for match in matches:
   print(match)
# Out:
# <re.Match object; span=(41943, 41946), match='dat'>
# <re.Match object; span=(157384, 157387), match='dat'>
# <re.Match object; span=(218933, 218936), match='dat'>
# <re.Match object; span=(281923, 281926), match='hat'>

# %%
# find the specific words by using word boundary and findall and matches the length.
# for case sensitivity we use flag re.IGNORECASE pr re.I
#  Matching dutch
pattern = re.compile(r'\bdutch\b', re.I)
matches = pattern.findall(contents)
print(matches)
len(matches)
# Out:
# ['Dutch', 'DUTCH', 'Dutch', 'Dutch', 'Dutch', 'Dutch', 'Dutch', 'Dutch', 'Dutch', 'Dutch', 'Dutch', 'Dutch', 'Dutch', 'Dutch', 'Dutch', 'Dutch', 'Dutch', 'Dutch', 'Dutch', 'Dutch', 'Dutch', 'Dutch', 'Dutch', 'Dutch', 'Dutch', 'Dutch', 'Dutch', 'Dutch', 'Dutch']
# 29

# %%
# Matching Portuguese
pattern = re.compile(r'\bportuguese\b', re.IGNORECASE)
matches = pattern.findall(contents)
print(matches)
len(matches)
# Out:
# ['Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Portuguese', 'Po
# ...

# %%
# Matching kling community
pattern = re.compile(r'\bkling\b', re.IGNORECASE)
matches = pattern.findall(contents)
print(matches)
len(matches)
# Out:
# []
# 0

# %%
# Matching tax
pattern = re.compile(r'\btax\b', re.IGNORECASE)
matches = pattern.findall(contents)
print(matches)
len(matches)
# Out:
# ['tax', 'tax', 'tax', 'tax', 'tax', 'tax']
# 6

# %%
# Matching malacca
pattern = re.compile(r'\bmalacca\b', re.IGNORECASE)
matches = pattern.findall(contents)
print(matches)
len(matches)
# Out:
# ['Malacca', 'Malacca', 'Malacca', 'Malacca']
# 4

# %%
# Matching year.
pattern = re.compile(r'\d\d\d\d', re.IGNORECASE)
matches = pattern.findall(contents)
print(matches)
len(matches)
# Out:
# ['2025', '7596', '1916', '7596', '1608', '1633', '1916', '1608', '1633', '1916', '1916', '1914', '1608', '1868', '1604', '1864', '1625', '1602', '1598', '1602', '1608', '1609', '1617', '1618', '1635', '1817', '1916', '1633', '1879', '1845', '1633', '1720', '1493', '1494', '1480', '1553', '1314', '1357', '1420', '1437', '1259', '1477', '1595', '1519', '1606', '1607', '1894', '1901', '1899', '1908', '1868', '1604', '1609', '1612', '1658', '1904', '1613', '1872', '1257', '1133', '1257', '1258', '1257', '1168', '1169', '1552', '1608', '1588', '1523', '1584', '1480', '1546', '1521', '1557', '1686', '1512', '1577', '1762', '1613', '1327', '1406', '1492', '1550', '1508', '1551', '1527', '1591', '1227', '1274', '1912', '1581', '1649', '1469', '1534', '1509', '1559', '1445', '1509', '1493', '1570', '1640', '1621', '1445', '1427', '1503', '1407', '1509', '1566', '1558', '1506', '1580', '1257', '1133', '1257', '1258', '1257', '1335', '2001', '6221', '0704', '9288']
# 121
